# %% [markdown]
# # WK1 Setting Up Jupyter <hr style="border:2.5px solid #126782"></hr>

# %% [markdown]
# **Gyro A. Madrona**

# %% [markdown]
# import pandas, numpy, matplotlib

# %% [markdown]
# Create a football player **name**, **kit_number**, and **rating** list

# %% [markdown]
# Convert the lists into a **dataframe**
